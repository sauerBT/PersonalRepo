# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read the RadNet dataset from the U.S. Environmental Protection Agency.

# %%
filePath = "C:\\Users\\brian\\GIT\\BrianPersonalCodingRepo\\PracticeScripts\\Python_Scripts\\06_Big Data Analysis with Python\\radData.csv" 
df = pd.read_csv(filePath)
df.head()
# Out:
#   State Location Date Posted Date Collected Sample Type    Unit  Ba-140  \
# 0    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3     0.0
# 1    ID    Boise  03/30/2011     03/23/2011  Air Filter  pCi/m3     0.0
# 2    AK   Juneau  03/30/2011     03/23/2011  Air Filter  pCi/m3     0.0
# 3    AK     Nome  03/30/2011     03/22/2011  Air Filter  pCi/m3     0.0
# 4    AK     Nome  03/30/2011     03/23/2011  Air Filter  pCi/m3     0.0
#
#    Co-60  Cs-134  Cs-136  Cs-137  I-131  I-132  I-133  Te-129  Te-129m  \
# 0    0.0       0     NaN       0      0      0    0.0     NaN      NaN
# 1    0.0       0     NaN       0      0      0    0.0     NaN      NaN
# 2    0.0       0     NaN       0      0      0    0.0     NaN      NaN
# 3    0.0       0     NaN       0      0      0    0.0     NaN      NaN
# 4    0.0       0     NaN       0      0      0    0.0     NaN      NaN
#
#    Te-132  Ba-140.1
# 0       0       NaN
# 1       0       NaN
# 2       0       NaN
# ...

# %% [markdown]
# Create a list with numeric columns for radionuclides in the RadNet dataset.

# %%
dfRad = df[list(df)[6:17]]
print(df)
# Out:
#     State        Location Date Posted Date Collected     Sample Type    Unit  \
# 0      ID           Boise  03/30/2011     03/23/2011      Air Filter  pCi/m3
# 1      ID           Boise  03/30/2011     03/23/2011      Air Filter  pCi/m3
# 2      AK          Juneau  03/30/2011     03/23/2011      Air Filter  pCi/m3
# 3      AK            Nome  03/30/2011     03/22/2011      Air Filter  pCi/m3
# 4      AK            Nome  03/30/2011     03/23/2011      Air Filter  pCi/m3
# ..    ...             ...         ...            ...             ...     ...
# 601    CA        Richmond  04/25/2011     04/14/2011  Precipitation    pCi/l
# 602    CA        Richmond  05/24/2011     04/28/2011  Precipitation    pCi/l
# 603    UT  Salt Lake City  05/24/2011     04/14/2011  Precipitation    pCi/l
# 604    UT  Salt Lake City  05/24/2011     04/28/2011  Precipitation    pCi/l
# 605    NY         Yaphank  05/24/2011     04/28/2011  Precipitation    pCi/l
#
# ...

# %% [markdown]
# Use the apply method on one column, with a lambda function that compares the Non-detect string.

# %%
df.apply(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-bb42b0f1a707> in <module>
# ----> 1 df.apply(2)
#
# c:\users\brian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# c:\users\brian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# c:\users\brian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
# ...
