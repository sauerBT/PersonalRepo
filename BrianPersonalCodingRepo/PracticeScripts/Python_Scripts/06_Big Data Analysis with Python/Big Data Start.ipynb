# %%
x = 2
print(x*2)
# Out:
# 4

# %% [markdown]
# The mean function calculates the arithmetic mean between two functions.
# ![image.png](attachment:image.png)
#
# $f(x)=\int_{-\infty}^{\infty} e^{-2ikx}f(k)$

# %%
def mean(a,b):
    return (a+b)/2

# %%
mean(10,20)
# Out:
# 15.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\brian\\Desktop\\Share\\R502P15016_Data_Log_2019-09-12.csv')
df.head()
# Out:
#          date      time  accel (g)  power (%)  accel sp (g)  \
# 0  2019-09-12  11:47:09       1.58        0.0            15
# 1  2019-09-12  11:47:10       3.75        1.6            15
# 2  2019-09-12  11:47:11       9.81        0.7            15
# 3  2019-09-12  11:47:12      10.49        1.8            15
# 4  2019-09-12  11:47:13      12.35        0.9            15
#
#    phase angle (deg)  frequency (Hz)  vessel temp. (degF)  \
# 0                 34           62.00                67.62
# 1                 50           62.00                67.62
# 2                 88           62.11                67.62
# 3                123           61.97                67.62
# 4                 94           61.97                67.62
#
#    vessel temp. #2 (degF)  vessel temp. #3 (degF)  ...  vessel vac. sp (torr)  \
# 0                  431.85                    32.0  ...                  760.0
# 1                  431.73                    32.0  ...                  760.0
# ...
